# %% [markdown]
# # Python编程入门
# Python程序分解：
# * 模块
# * 语句
# * 表达式

# %% [markdown]
# 例子：72法则是一个计算资产翻倍所需时间的经验法则（年利率一定）。

# %%
import math
# the rule of 72
x_values = list(range(1, 10))
y_values = []
for i in range(1,10):
    j = i/100
    n = math.log(2)/math.log(1+j) # (1+j)^n=2
    y_values.append(n)
    print(i,'%->',round(n),end='\t')
print()
print(x_values)
print(y_values)
# Out:
# 1 %-> 70	2 %-> 35	3 %-> 23	4 %-> 18	5 %-> 14	6 %-> 12	7 %-> 10	8 %-> 9	9 %-> 8
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [69.66071689357483, 35.0027887811465, 23.449772250437736, 17.672987685129698, 14.206699082890461, 11.895661045941875, 10.244768351058712, 9.006468342000588, 8.043231726932046]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(x_values, y_values)
ax.set_title('72 law')
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %%
import numpy as np
import random
r = 3
prmt = 2*math.pi*r  # 圆的周长
area = math.pi*r**2  # 圆的面积
print("The perimeter is:", prmt)
print("The area is:", area)
x = []
y = []
while len(x) <= 10000:
    tmp1 = (random.random() * 6 - 3)
    tmp2 = (random.random() * 6 - 3)
    if (tmp1 ** 2 + tmp2 ** 2) <= 9:
        x.append(tmp1)
        y.append(tmp2)

fig2, ax2 = plt.subplots()
ax2.scatter(x, y)
plt.show()
# Out:
# The perimeter is: 18.84955592153876
# The area is: 28.274333882308138

# %% [markdown]
# ## Python语句
# * 语句是Python代码的基本单元
# * 语句实现各种不同功能：赋值、调用函数、控制程序流程、引入外部代码块等
# * 简单语句一般只有一行
# * 复合语句包含子代码块

# %%
a=10; b=20
area=a*b
c=(a+2*b+
   b**2)+2
print(c)
# Out:
# 452

# %% [markdown]
# * 一行只有一条语句时，不需要加结束符
# * 一行中有多条语句时，用分号分隔
# * 语句需要跨行时，可以使用反斜杠‘\’
# * 当含有括号（大中小）时，语句在右括号结束

# %%
a_very_long_very_long_line = 55 + 23 + 3.14*6500 \
    + 25 + 30
a_very_long_very_long_line
# Out:
# 20543.0

# %% [markdown]
# ### 大家来改错
# 以下代码有一些错误，看看你是否能够找出来。把每行开头的#号去掉运行。

# %%
#  i1 ＝ 2 5 ＃　定义一个变量
#print(il)　＃　把变量的值打印出来
#if i1 > = 0:
#    print 'positive'
i, l = 2, 5
print(i, l)
if i * l >= 0:
    print('positive')
# Out:
# 2 5
# positive

# %% [markdown]
# ## Python语言形式规则
#
# 1) 缩进(indent)
# * 缩进表示不同层次的代码块
# * 同一代码块的缩进必须一致
# * 建议缩进统一使用四个空格
#
# 比较下面两段看起来很相似的代码。

# %%
s = 0
for i in range(5):
    s = s+i
    print(s)
# Out:
# 0
# 1
# 3
# 6
# 10

# %%
s = 0
for i in range(5):
    s = s+i
print(s)
# Out:
# 10

# %% [markdown]
# 注意上述两段代码中的print(s)语句，由于处在不同层次的代码块中，因此执行的时机并不相同。

# %% [markdown]
# 子代码块未缩进会导致错误。

# %%
s = 0
#for i in range(10):
#    if i%2==0:
#    s = s+i
print(s)
# Out:
# 0

# %% [markdown]
# 同一个子代码块缩进不同也会导致错误。不同的子代码块缩进不同不会报错，但不建议这样写。

# %%
i = 2503
if i%7==0:
  s=i
#    print("ok")  # 缩进不统一
else:
      print("not ok")  # 缩进不统一
# Out:
# not ok

# %% [markdown]
# 2）代码和注释
# * 注释部分以#开始，直到该行的结束
# * 注释可以出现在任何位置
# * 注释可以帮助程序代码阅读和理解
# * 暂时不执行的语句可以注释掉

# %%
def get_value(b,r,n):  # 根据初始值、利率和期数计算终值
    # b=初始值，r=利率，n=期数
    v = b*((1+r)**n)
    return v
total = get_value(10,0.05,20)
print(total)
# Out:
# 26.53297705144422

# %%
for i in range(5):
    #print(i)  # will not run
    print('*'*i)
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# 3）语句的结束
# * 简单语句到换行符结束
# * 简单语句到分号结束
# * 简单语句到配对括号结束
# * 复合语句到结构体尾部结束
# * 代码跨行可以使用反斜杠'\'，表示该行代码未结束

# %%
a = 5; b = 6
c = a**2-3*b
d = a + (c -
        2*a)
for i in range(a):
    print(i)
print(a,b,c,d)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5 6 7 2

# %% [markdown]
# 试试看，改正以下代码。把每行开头的#号去掉再运行。

# %%
# 这行是注释
ａ = 5 % 3
if 5 > 3:
   print('ok')
# Out:
# ok

# %% [markdown]
# 4）语句和表达式使用英文半角符号
# * Python语句和各种操作符使用符号皆为英文半角
# * 即便是英文符号也需要注意是否为半角
# * 若使用了中文符号，错误信息一般为语法错
# * 有些全角符号不可见，难以发现，如四个全角空格

# %% [markdown]
# 5）大小写敏感
# * Python中所有标识符大小写敏感
# * 命令通常为小写
# * 常量名通常使用大写

# %%
Hello = 5
Hell0 = 6
HellO = 7
#print(hell0)

# %% [markdown]
# 除了大小写之外，需要特别注意的是一些形状相似的符号，如O和0，1和l.
#
# 要避免这个问题，在写程序代码的时候，要善于使用自动完成功能。

# %% [markdown]
# 思考：如何发现在程序代码中存在多个相似的名字？

# %%
# 列出当前名称空间中的所有名称
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# a          int       2
# area       float     28.274333882308138
# ax         Axes      Axes(0.125,0.11;0.775x0.77)
# ax2        Axes      Axes(0.125,0.11;0.775x0.77)
# b          int       6
# c          int       7
# d          int       2
# fig        Figure    Figure(640x480)
# fig2       Figure    Figure(640x480)
# i          int       4
# j          float     0.09
# l          int       5
# math       module    <module 'math' from '/hom<...>311-x86_64-linux-gnu.so'>
# n          float     8.043231726932046
# np         module    <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# plt        module    <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# prmt       float     18.84955592153876
# r          int       3
# random     module    <module 'random' from '/h<...>ib/python3.11/random.py'>
# tmp1       float     0.7279135741205955
# tmp2       float     1.7827587371581268
# x          list      n=10001
# x_values   list      n=9
# y          list      n=10001
# y_values   list      n=9

# %% [markdown]
# 6) 空白。程序代码中可以插入空白，以增强代码可读性。
#
# 空白可以出现在操作符与操作数之间，但由多个字符组成的一个整体操作符或操作数不能插入空白，如变量名、操作数、操作符（如**,//)等等。

# %%
#a = 2 5
#b = 3 * * 3
#a + = 5

# %% [markdown]
# ## 标识符
# * 标识符指的是变量、函数、类、对象、模块等的名称
# * 标识符只能由字母、数字和下划线组成
# * 标识符首字符必须是字母或下划线
# * 系统保留关键字不能作为标识符

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# 下列名称哪些可以作为标识符使用？
#
# a_very_long_int, class, school, stop, continue, not, otherwise, while, 9527, notMe,isn't, me, and-u,true

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'aiter',
#  'all',
#  'anext',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'execfile',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'runfile',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %% [markdown]
# * Python语言还包含许多预定义内置类、异常、top-level函数
# * 用户自定义标识符应当回避预定义标识符
# * 用户自定义标识符会覆盖预定义标识符，使其失效
# * 在引入包时，为了避免命名冲突，尽量不使用from 包名 import *

# %% [markdown]
# 标识符命名规则
# * 模块、包、函数、变量名使用全小写字母
# * 类名使用多个单词，单词首字母大写
# * 常量名使用全大写字母
# * 可以使用下划线提高标识符的可读性

# %% [markdown]
# ## 表达式
# * 表达式将一些操作数由运算符连接起来，完成某种特定的计算操作
# * 表达式的运算结果为某种对象
# * 运算结果对象的类型由操作数和运算符共同决定
# * 操作数必须与运算符相兼容（运算必须在该对象上有定义）

# %%
a = 2 + 10
b = 3*4
c = 23//5 # 这是一个整数除法
d = 23%5
(a,b,c,d)
# Out:
# (12, 12, 4, 3)

# %% [markdown]
# * 简单表达式含有一个运算符，运算顺序从左到右。
# * 表达式中乘号不能省略。
# * 可以使用type()函数查看结果对象的类型。

# %%
type(a),type(b),type(c),type(d)
# Out:
# (int, int, int, int)

# %%
a = 1+2-3*4/5
b = (1+2-3)*4/5
c = 3**3**2
(a,b,c)
# Out:
# (0.6000000000000001, 0.0, 19683)

# %% [markdown]
# * 复合表达式含有两个以上运算符
# * 运算顺序取决于运算符的优先级和结合顺序（左、右）
# * 可以使用小（圆）括号改变运算顺序
# * python语言里中（方）括号和大（花）括号具有特殊含义，不能用于改变运算顺序

# %% [markdown]
# 一般顺序：
#
# 乘方运算 > 乘除 > 加减 > 比较运算 > 集合运算 > 逻辑运算
#
# 猜猜下面表达式的运算结果

# %%
# 这里第一个不是一个判断语句，所以都是True，or直接就偷懒不看后面的了
print(type(5//2 or 2+3 > 4))
print(type(5//2 and 2 + 3 > 4))
# Out:
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ## 变量和赋值
# * 为了定位数据，计算机将数据绑定给变量，用变量名指代需要处理的数据
# * 变量实际上是一个对象的引用
# * 变量必须初始化之后才能被访问
#
# **在Python中数据对象是核心，变量仅仅是一个名字。**

# %%
x=1;y=1;z=2
# python中id用于获取变量的地址
id(x),id(y),id(z)
# Out:
# (8885320, 8885320, 8885352)

# %% [markdown]
# 假如你想要在改变list_1之前，先做一个备份，然后再修改list_1的值。这样做是否能够得到想要的结果？
# 为什么呢？

# %%
list_1 = [5,2,3,1]
list_2 = list_1
list_1[2] = 6.5
# 如果是一个list不能直接=，不然就是值向同一个列表对象
list_2  # guess?
# Out:
# [5, 2, 6.5, 1]

# %% [markdown]
# ### 链式赋值
#
# 赋值运算是右结合的。首先生成对象3，然后将其地址传给z，然后传给y，然后传给x

# %%
x=y=z=3
print(id(x), id(y), id(z))
# 后面直接打id会发现
# Out:
# 8885384 8885384 8885384

# %% [markdown]
# ### 复合赋值
#
# 当赋值变量的表达式含有赋值变量自身时，往往可以采用这种简化的形式。
# 例如：x=x\*5 可以简化为 x\*=5。如常用的自增和自减。

# %%
i = 1
# 注意，。python中没有++, --操作：invalid syntax
i +=1
i
# Out:
# 2

# %% [markdown]
# * 元组(tuple)解包可以批量给一组变量赋值
#
# * 元组解包顺序从左到右
#
# * 赋值元组和解包元组长度必须一致

# %%
a,b,c = 1,2,3
a,b,c
# Out:
# (1, 2, 3)

# %% [markdown]
# ## 程序流程控制
#
# * 分支结构
# * 循环结构

# %% [markdown]
# 分支结构根据某个关键值是否满足特定条件，决定执行哪个代码块。在设计分支条件时需要仔细分析。

# %%
x = int(input("please input an integer"))
if x % 2 == 0:
    print('even')
else:
    print('odd')
# Out:
# please input an integer124
# even

# %% [markdown]
# 循环结构根据条件重复执行某个代码块，或者执行某个代码块指定次数。

# %%
x = 100
s = 0
for i in range(x):
    s+=i
print(s)
# Out:
# 4950

# %% [markdown]
# ## 代码编写与调试

# %% [markdown]
# * 编写代码容易出错（拼写错误，语法错误，逻辑错误）(spelling error, syntax error, logic error)
# * 代码越长越容易出错
# * 编译器提示的错误位置未必是真实发生错误的地方

# %% [markdown]
# 代码编写策略
#
# * 尽量写短的代码
# * 代码越简单越好
# * 代码分块编写与调试
# * 善于利用交互式解释运行环境

# %% [markdown]
# ## Python代码块
# * 函数(function)
# * 类(class)
# * 模块(module)
# * 包(package)

# %% [markdown]
# 当代码量增加到一定数量时，会产生几个问题：
# * 命名冲突
# * 无意识的修改
# * 代码重用
# * 任务分解和协调问题

# %% [markdown]
# ### 函数
#
# * 将相对独立的、经常执行的任务进行封装，隐藏其内部实现和内部变量。
# * 函数的作用在于实现程序的模块化设计和代码重用。
# * 只需要知道函数的接口（调用方式）、函数的功能

# %%
a = 5
def power_it(a, b = 2):
    a = a ** b
    return a
print(power_it(10), power_it(10, 3))
print(a)
# Out:
# 100 1000
# 5

# %% [markdown]
# ### 类
#
# * 将事物的属性与操作进行捆绑
# * 利用类的方法、类的继承实现代码重用
# * 提高代码的可靠性和可维护性

# %%
class Light:
    def __init__(self, degree):
        self.degree = degree
# 类的继承 inheritance
class Half_Light(Light):
    def __init__(self, degree, age):
        Light.__init__(self, degree/2)
        self.age = age
light1 = Half_Light(10, 8)
print(light1.degree, light1.age)
# Out:
# 5.0 8

# %% [markdown]
# ### 模块 (module)
#
# * 一个代码文件即为一个module
# * 处理特定任务的代码可以组织在一个模块中
# * 用import语句可以将module中的代码导入使用
# * 注意写一个:
#         if __name__ == "__main__":
#             func()
#     防止模块调用的时候直接执行

# %% [markdown]
# ### 包 (package)
#
# * 可以将若干个模块组织成一个包
# * 包是模块的层次性组织结构，类似于文件夹(比directory多出一个init.py文件)
# * 可以使用import语句引入包
# * 使用包可以有效解决命名空间冲突问题

# %%
# %whos
# Out:
# Variable     Type          Data/Info
# ------------------------------------
# Half_Light   type          <class '__main__.Half_Light'>
# Light        type          <class '__main__.Light'>
# a            int           2
# area         float         28.274333882308138
# ax           Axes          Axes(0.125,0.11;0.775x0.77)
# ax2          Axes          Axes(0.125,0.11;0.775x0.77)
# b            int           6
# c            int           7
# d            int           2
# fig          Figure        Figure(640x480)
# fig2         Figure        Figure(640x480)
# i            int           2
# j            float         0.09
# l            int           5
# light1       Half_Light    <__main__.Half_Light object at 0x7f5cdf6ac090>
# list_1       list          n=4
# list_2       list          n=4
# math         module        <module 'math' from '/hom<...>311-x86_64-linux-gnu.so'>
# n            float         8.043231726932046
# np           module        <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# plt          module        <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# prmt         float         18.84955592153876
# r            int           3
# random       module        <module 'random' from '/h<...>ib/python3.11/random.py'>
# tmp1         float         0.7279135741205955
# tmp2         float         1.7827587371581268
# x            int           124
# x_values     list          n=9
# y            int           1
# y_values     list          n=9
# z            int           2

# %%
from datetime import date,time,datetime

# %%
# %whos  # 检查名称空间中出现了哪些名字
# Out:
# No variables match your requested type.

# %%
dat1 = datetime.now()
print(dat1)
type(dat1)
# Out:
# 2024-04-08 07:21:23.616883
# datetime.datetime

# %%
dat1.date()
# Out:
# datetime.date(2024, 4, 8)

# %%
dir(date)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  'ctime',
#  'day',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'min',
#  'month',
#  'replace',
#  'resolution',
#  'strftime',
#  'timetuple',
#  'today',
#  'toordinal',
#  'weekday',
#  'year']
